# %%
import networkx as nx
import matplotlib.pylab as plt
rms=nx.read_edgelist("mylist.txt")
print(nx.info(rms))
nx.draw(rms)

print("The average clustering is :",nx.average_clustering(rms))
print("Diameter of graph is: ",nx.diameter(rms))
plt.show()
# Out:
# Name:
# Type: Graph
# Number of nodes: 31
# Number of edges: 231
# Average degree:  14.9032
# The average clustering is : 0.8600112602534453
# Diameter of graph is:  3
